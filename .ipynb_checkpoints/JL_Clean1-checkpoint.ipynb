# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\erins\OneDrive\Desktop\MS_Data_analytics\44-688\Capstone_Project\scraping-glassdoor-selenium\Company_Rating_Data_Full_Clean.csv", encoding='latin-1')

# %%
df.corr()
# Out:
# C:\Users\erins\AppData\Local\Temp\ipykernel_16792\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         Global Size  Company Rating  Company Ownership Type  \
# Global Size                1.000000       -0.261301                0.179730
# Company Rating            -0.261301        1.000000               -0.141218
# Company Ownership Type     0.179730       -0.141218                1.000000
# Company Age                0.465822       -0.120067                0.164250
# Est Yearly Revenue         0.840729       -0.231648                0.144854
#
#                         Company Age  Est Yearly Revenue
# Global Size                0.465822            0.840729
# Company Rating            -0.120067           -0.231648
# ...

# %%
df[['Company Rating','Global Size','Est Yearly Revenue','Company Ownership Type','Company Age']].corr()
# Out:
#                         Company Rating  Global Size  Est Yearly Revenue  \
# Company Rating                1.000000    -0.261301           -0.231648
# Global Size                  -0.261301     1.000000            0.840729
# Est Yearly Revenue           -0.231648     0.840729            1.000000
# Company Ownership Type       -0.141218     0.179730            0.144854
# Company Age                  -0.120067     0.465822            0.442955
#
#                         Company Ownership Type  Company Age
# Company Rating                       -0.141218    -0.120067
# Global Size                           0.179730     0.465822
# Est Yearly Revenue                    0.144854     0.442955
# Company Ownership Type                1.000000     0.164250
# Company Age                           0.164250     1.000000

# %%
df.describe()
# Out:
#        Global Size  Company Rating  Company Ownership Type  Company Age  \
# count  3827.000000     3827.000000             3827.000000  3827.000000
# mean      4.366083        3.630024                3.410766    48.407369
# std       1.907843        0.574970                2.813058    44.025096
# min       1.000000        1.000000                1.000000     3.000000
# 25%       3.000000        3.300000                2.000000    21.000000
# 50%       5.000000        3.600000                2.000000    31.000000
# 75%       6.000000        4.000000                3.000000    59.000000
# max       7.000000        5.000000               13.000000   355.000000
#
#        Est Yearly Revenue
# count         3827.000000
# mean             7.209302
# std              2.921671
# min              1.000000
# 25%              5.000000
# 50%              7.000000
# 75%             10.000000
# max             12.000000

# %%
df.columns
# Out:
# Index(['Company Name', 'Global Size', 'Company Rating',
#        'Company Ownership Type', 'Company Age', 'Est Yearly Revenue'],
#       dtype='object')

# %%
df['Global Size'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Company Rating'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Company Ownership Type'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Company Age'].hist() # Exponential Distro
# Out:
# <AxesSubplot:>

# %%
df['Est Yearly Revenue'].hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'Company Rating')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'Company Age')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
cmap = sns.diverging_palette(220, 10, as_cmap = True)
sns.heatmap(df[['Company Rating','Global Size','Est Yearly Revenue','Company Ownership Type','Company Age']].corr(), vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>
